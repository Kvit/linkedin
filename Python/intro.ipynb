# %%
#  Make LinkedIn Introduction with Google Gemini

import os
import json
import time
from google.cloud import firestore
from google.api_core.exceptions import DeadlineExceeded
from google.api_core.retry import Retry
from google import genai
from google.genai import types
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Initialize the Gemini client (auto-detects GOOGLE_API_KEY from environment)
client = genai.Client()


def show_json(obj):
    display(json.loads(obj.model_dump_json()))


# Initialize Firestore client with specific project ID, only if file is found
if os.path.isfile("vk-linkedin-master-service-account.json"):
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = (
        "vk-linkedin-master-service-account.json"
    )

db = firestore.Client(project="vk-linkedin", database="linkedin")

# Get the 'extracted' collection
extracted_ref = db.collection("extracted")

# analysis collection
analysis_ref = db.collection("analysis")

# %%
# System instructions for generating LinkedIn introductions
INTRO_INSTRUCTIONS = """You are an expert at writing personalized LinkedIn connection request introductions.
Based on the provided profile summary, write a brief, professional, and friendly introduction message.
Keep it concise (2-3 sentences), mention something specific from their background, and express genuine interest in connecting.
Do not be overly formal or use generic phrases like "I came across your profile"."""


def make_intro(summary: str) -> str | None:
    """
    Generate a LinkedIn introduction from a profile summary using Google Gemini.

    Args:
        summary (str): The profile summary to analyze.

    Returns:
        str | None: The generated introduction or None if an error occurs.
    """
    try:
        response = client.models.generate_content(
            model="gemini-3.1-pro-preview",
            contents=summary,
            config=types.GenerateContentConfig(
                system_instruction=INTRO_INSTRUCTIONS,
            ),
        )
        return response.text

    except Exception as e:
        print(f"Error generating intro: {e}")
        return None

# %%
# helper function to get intro from summary
def get_intro(summary: str) -> str | None:
    """
    Get an introduction from a summary using Google Gemini.

    Args:
        summary (str): The summary to analyze.

    Returns:
        str | None: The generated intro or None if an error occurs.
    """
    try:
        intro = make_intro(summary)
        return intro
    except Exception as e:
        print(f"Error analyzing summary: {e}")
        return None

# %%
# process all documents in collection `extracted` via generator

# retry policy for DeadlineExceeded in case of timeout in Firestore
retry = Retry(predicate=lambda e: isinstance(e, DeadlineExceeded))

# get docs
docs = extracted_ref.stream(retry=retry)

# process docs
for doc in docs:
    doc_dict = doc.to_dict()

    # check if the document already exists
    doc_id = doc.id
    doc_ref = analysis_ref.document(doc_id)

    # skip if intro already exists in the document
    if "intro" in doc_dict:
        continue

    summary = doc_dict["summary"].replace("\n", " ")

    if len(summary) > 50:
        # get analysis of summary via OpenAI Assistant
        try:
            intro = get_intro(summary)

            # update document with intro if available
            if intro is not None:
                update_doc = {
                    "profileUrl": doc_dict["profileUrl"],
                    "lh_id": doc_dict["lhId"],
                    "summary": summary,
                    "intro": intro,
                }

                analysis_ref.document(doc_id).set(
                    update_doc,
                    retry=Retry(predicate=lambda e: isinstance(e, DeadlineExceeded)),
                )
        except Exception as e:
            print(e)
            time.sleep(10)
            continue
