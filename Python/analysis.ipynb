# %%
#  Make analysis of LinkedIn profile data

import os
import time
import pprint
import polars as pl
from google.cloud import firestore
from google.api_core import retry
from google import genai
from google.genai import types
from pydantic import BaseModel
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Initialize the Gemini client (auto-detects GOOGLE_API_KEY from environment)
client = genai.Client()

# Initialize Firestore client with specific project ID, only if file is found
if os.path.isfile("vk-linkedin-master-service-account.json"):
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = (
        "vk-linkedin-master-service-account.json"
    )

db = firestore.Client(
    project="vk-linkedin",
    database="linkedin"
)

# Get the 'extracted' collection
extracted_ref = db.collection("extracted")

# analysis collection
analysis_ref = db.collection("analysis")

# %%
# System instructions for analyzing LinkedIn profile summaries
ANALYSIS_INSTRUCTIONS = """You are an expert at analyzing LinkedIn profiles to identify potential buyers for a healthcare RCM (Revenue Cycle Management) technology company.

Our product, Recovr by Pinnacle Services, is AI-powered claim denial recovery software sold to:
- Pathology Practices
- Medical Diagnostic Laboratories  
- Revenue cycle management (RCM) firms and billing companies

Analyze the provided profile summary and classify using EXACTLY these controlled values:

## industry — Use one of:
- "RCM" — works at an RCM firm, billing company, or billing department
- "Pathology" — works in lab, pathology, or diagnostic services
- "Medical Lab" — works at a physician practice, clinic, or medical group
- "Hospital" — works at a hospital or integrated health system
- "Health IT" — works at a healthcare software or health tech vendor
- "Health Insurance Payer" — works on the payer or insurance side
- "Pharma" — pharmaceutical, biotech, or medical device company
- "Other Healthcare" — healthcare adjacent but none of the above
- "Non-Healthcare" — not in healthcare at all

## function — Use one of:
- "Operations" — operations, revenue cycle, billing, coding, claims, or collections role
- "Finance" — finance, accounting, or financial leadership role
- "IT" — information technology, software, or technical role
- "Clinical" — clinical role such as physician, nurse, or lab technician
- "Executive" — CEO, COO, CFO, or other executive role
- "Consulting" — works at a consulting firm or in a consulting role
- "Owner" — business owner, founder, or partner
- "Sales & Marketing" — sales, marketing, business development, or customer success role
- "Other" — none of the above or cannot determine from summary

## seniority — Use one of:
- "Executive" — CEO, CFO, COO, CTO, CMO, CIO, CRO
- "VP" — Vice President level
- "Director" — Director level
- "Manager" — Manager or Supervisor level
- "Staff" — staff-level, no direct reports
- "Owner" — business owner, partner, or founder
- "Unknown" — cannot determine from summary

If the summary is too short or vague to classify, use your best judgment from whatever context is available. Never return empty strings — use "Unknown" or "Other" when uncertain."""

# %%
# Pydantic model for structured output
class ProfileAnalysis(BaseModel):
    industry: str
    function: str
    seniority: str


def analyze_summary(summary: str) -> dict | None:
    """
    Analyze the summary using Google Gemini with structured output.

    Args:
        summary (str): The profile summary to analyze.

    Returns:
        dict | None: Dictionary with industry, function, seniority keys, or None on error.
    """
    summary_preview = summary[:100] + "..." if len(summary) > 100 else summary

    try:
        response = client.models.generate_content(
            model="gemini-3-flash-preview",
            contents=summary,
            config=types.GenerateContentConfig(
                system_instruction=ANALYSIS_INSTRUCTIONS,
                response_mime_type="application/json",
                response_schema=ProfileAnalysis,
            ),
        )

        # Parse and validate response via Pydantic
        result = ProfileAnalysis.model_validate_json(response.text)

        # Check for empty values
        empty_fields = [f for f in ["industry", "function", "seniority"]
                       if not getattr(result, f).strip()]
        if empty_fields:
            print(f"WARNING: Empty values for fields: {empty_fields}")
            print(f"Summary: {summary_preview}")

        return result.model_dump()

    except Exception as e:
        print(f"ERROR: {type(e).__name__}: {e}")
        print(f"Summary: {summary_preview}")
        return None

# %%
# Alias for backward compatibility with cell 5 call sites
get_analysis = analyze_summary

# %%
# helper function get member distance
def get_member_distance(doc_dict) -> int:
    """
    Extract member distance from various data formats.
    
    Handles:
    - Nested dict: {'memberDistance': {'memberDistance': 'DISTANCE_3', ...}}
    - Direct integer: {'memberDistance': 3}
    - Direct string: {'memberDistance': 'DISTANCE_3'}
    - Out of network: {'memberDistance': 'OUT_OF_NETWORK'} -> returns 0
    """
    try:
        member_dist = doc_dict.get("memberDistance")
        
        if member_dist is None:
            return 0
        
        # If it's a dict, extract the 'memberDistance' field
        if isinstance(member_dist, dict):
            str_distance = member_dist.get("memberDistance")
            if str_distance is None:
                return 0
        else:
            str_distance = member_dist
        
        # If it's already an integer, return it
        if isinstance(str_distance, int):
            return str_distance
        
        # If it's a string, try to parse the distance
        if isinstance(str_distance, str):
            if str_distance == "OUT_OF_NETWORK":
                return 0
            # Match "DISTANCE_X" pattern
            if str_distance.startswith("DISTANCE_") and str_distance[-1:].isdigit():
                return int(str_distance[-1:])
            return 0
        
        return 0
        
    except Exception as e:
        print(f"Error getting member distance: {e}, member_dist: {doc_dict.get('memberDistance')}")
        return 0

# %%
#  statistics 

# Get all documents from analysis collection
analysis_docs = list(analysis_ref.stream())

# Initialize counters
total_docs = len(analysis_docs)

if total_docs == 0:
    print("No documents found in analysis collection.")
else:
    with_all_categories = 0
    missing_categories = 0
    with_summary = 0
    without_summary = 0
    with_industry = 0
    with_function = 0
    with_seniority = 0
    with_summary_no_categories = 0

    # Count statistics
    for doc in analysis_docs:
        doc_data = doc.to_dict()
        
        # Check categories
        has_industry = bool(doc_data.get("industry"))
        has_function = bool(doc_data.get("function"))
        has_seniority = bool(doc_data.get("seniority"))
        
        if has_industry:
            with_industry += 1
        if has_function:
            with_function += 1
        if has_seniority:
            with_seniority += 1
        
        if has_industry and has_function and has_seniority:
            with_all_categories += 1
        else:
            missing_categories += 1
        
        # Check summary
        summary = doc_data.get("summary", "")
        has_summary = summary and len(summary.strip()) > 50
        
        if has_summary:
            with_summary += 1
        else:
            without_summary += 1
        
        # Check for summary but no categories
        if has_summary and not (has_industry and has_function and has_seniority):
            with_summary_no_categories += 1

    # Display statistics
    print("=" * 60)
    print("ANALYSIS COLLECTION STATISTICS")
    print("=" * 60)
    print(f"\nTotal documents: {total_docs}")
    print("\n--- Category Statistics ---")
    print(f"With all 3 categories (industry, function, seniority): {with_all_categories} ({with_all_categories/total_docs*100:.1f}%)")
    print(f"Missing one or more categories: {missing_categories} ({missing_categories/total_docs*100:.1f}%)")
    print(f"\nBreakdown by field:")
    print(f"  - With industry: {with_industry} ({with_industry/total_docs*100:.1f}%)")
    print(f"  - With function: {with_function} ({with_function/total_docs*100:.1f}%)")
    print(f"  - With seniority: {with_seniority} ({with_seniority/total_docs*100:.1f}%)")
    print("\n--- Summary Statistics ---")
    print(f"With summary: {with_summary} ({with_summary/total_docs*100:.1f}%)")
    print(f"Without summary: {without_summary} ({without_summary/total_docs*100:.1f}%)")
    print(f"With summary but no categories yet: {with_summary_no_categories} ({with_summary_no_categories/total_docs*100:.1f}%)")
    print("=" * 60)
# Out:
# ...
# ANALYSIS COLLECTION STATISTICS
# ...
#
# Total documents: 27766
#
# --- Category Statistics ---
# With all 3 categories (industry, function, seniority): 13130 (47.3%)
# Missing one or more categories: 14636 (52.7%)
#
# Breakdown by field:
#   - With industry: 13130 (47.3%)
#   - With function: 13130 (47.3%)
#   - With seniority: 13130 (47.3%)
#
# --- Summary Statistics ---
# With summary: 13130 (47.3%)
# Without summary: 14636 (52.7%)
# With summary but no categories yet: 0 (0.0%)
# ...

# %%
# ── Configuration ──────────────────────────────────────────────────────────────

# Set to True to force reprocess ALL records, ignoring existing analysis
REPROCESS_ALL = False

# retry policy with custom parameters
# reference https://cloud.google.com/spanner/docs/custom-timeout-and-retry?hl=en
my_retry = retry.Retry(
    initial=0.5,   # Initial delay of 0.5 seconds
    timeout=60,    # Maximum timeout of 60 seconds
    multiplier=2,  # Increase delay by 2x on each retry
)

# Firestore batch write limit
BATCH_SIZE = 500

print("Configuration ready.")
if REPROCESS_ALL:
    print("⚠️  REPROCESS_ALL=True — all records will be reanalyzed.")
# Out:
# Configuration ready.

# %%
# ── Phase A: Bulk-fetch `extracted` collection into a Polars DataFrame ─────────
# One stream replaces N individual .get() calls for the extracted docs.

print("Phase A: streaming 'extracted' collection...")

extracted_rows = []
for doc in extracted_ref.stream():
    d = doc.to_dict()
    summary = d.get("summary", "") or ""
    summary = summary.replace("\n", " ")
    extracted_rows.append({
        "doc_id":       doc.id,
        "summary":      summary,
        "profileUrl":   d.get("profileUrl", "") or "",
        "lh_id":        str(d.get("lhId", "") or ""),
        "memberDistance": get_member_distance(d),
    })

df_extracted = pl.from_dicts(
    extracted_rows,
    schema={
        "doc_id":         pl.Utf8,
        "summary":        pl.Utf8,
        "profileUrl":     pl.Utf8,
        "lh_id":          pl.Utf8,
        "memberDistance": pl.Int64,
    },
)

print(f"  extracted docs loaded: {len(df_extracted)}")
# Out:
# Phase A: streaming 'extracted' collection...
#   extracted docs loaded: 27777

# %%
# ── Phase B: Bulk-fetch `analysis` collection into a Polars DataFrame ──────────
# One stream reads all existing analysis docs — no per-doc .get() needed.

print("Phase B: streaming 'analysis' collection...")

analysis_rows = []
for doc in analysis_ref.stream():
    d = doc.to_dict()
    analysis_rows.append({
        "doc_id":    doc.id,
        "summary":   (d.get("summary", "") or "").replace("\n", " "),
        "industry":  d.get("industry", "") or "",
        "function":  d.get("function", "") or "",
        "seniority": d.get("seniority", "") or "",
    })

ANALYSIS_SCHEMA = {
    "doc_id":    pl.Utf8,
    "summary":   pl.Utf8,
    "industry":  pl.Utf8,
    "function":  pl.Utf8,
    "seniority": pl.Utf8,
}

df_analysis = pl.from_dicts(analysis_rows, schema=ANALYSIS_SCHEMA) if analysis_rows else pl.DataFrame(schema=ANALYSIS_SCHEMA)

print(f"  analysis docs loaded: {len(df_analysis)}")
# Out:
# Phase B: streaming 'analysis' collection...
#   analysis docs loaded: 27766

# %%
# ── Phase C: Polars join → identify reprocess vs update-only docs ──────────────
#
# Left-join extracted onto analysis on doc_id.
# A doc needs Gemini reprocessing when ANY of:
#   1. Not in analysis at all (new doc)                            → summary_existing is null
#   2. Summary has changed since last run                          → summary != summary_existing
#   3. Categories are missing/empty AND summary is long enough     → empty fields + len > 50
#
# All reprocess candidates must have summary > SUMMARY_MIN_LEN.
# Update-only = existing docs that don't need reprocessing.
# New docs with short summaries are skipped entirely (no write).
#
# When REPROCESS_ALL=True, skip the join and flag everything with len(summary)>50.

SUMMARY_MIN_LEN = 50

if REPROCESS_ALL:
    df_reprocess   = df_extracted.filter(pl.col("summary").str.len_chars() > SUMMARY_MIN_LEN)
    df_update_only = pl.DataFrame(schema=df_extracted.schema)
else:
    # left join — analysis columns get suffix "_existing"
    joined = df_extracted.join(
        df_analysis.rename({
            "summary":   "summary_existing",
            "industry":  "industry_existing",
            "function":  "function_existing",
            "seniority": "seniority_existing",
        }),
        on="doc_id",
        how="left",
    )

    has_long_summary  = pl.col("summary").str.len_chars() > SUMMARY_MIN_LEN
    is_new            = pl.col("summary_existing").is_null()
    is_existing       = ~is_new
    summary_changed   = pl.col("summary") != pl.col("summary_existing").fill_null("")
    missing_industry  = pl.col("industry_existing").is_null()  | (pl.col("industry_existing")  == "")
    missing_function  = pl.col("function_existing").is_null()  | (pl.col("function_existing")  == "")
    missing_seniority = pl.col("seniority_existing").is_null() | (pl.col("seniority_existing") == "")
    missing_categories = missing_industry | missing_function | missing_seniority

    # Reprocess: must have long summary AND (new | summary changed | missing categories)
    needs_reprocess = (is_new | summary_changed | (missing_categories & has_long_summary)) & has_long_summary

    # Update-only: existing docs that don't need reprocessing (any summary length)
    update_only = is_existing & ~needs_reprocess

    df_reprocess   = joined.filter(needs_reprocess).select(df_extracted.columns)
    df_update_only = joined.filter(update_only).select(df_extracted.columns)

skipped = len(df_extracted) - len(df_reprocess) - len(df_update_only)

print(f"Phase C results:")
print(f"  Total extracted:  {len(df_extracted)}")
print(f"  → Needs Analysis:   {len(df_reprocess)}")
print(f"  → Already Analyzed:    {len(df_update_only)}")
print(f"  → Skipped (new w/ short summary): {skipped}")
# Out:
# Phase C results:
#   Total extracted:  27777
#   → Needs Analysis:   6
#   → Already Analyzed:    27766
#   → Skipped (new w/ short summary): 5

# %%
# ── Phase D: Gemini analysis for docs in df_reprocess ─────────────────────────
# Only this filtered subset hits the Gemini API — not the full collection.

reprocess_rows = df_reprocess.to_dicts()
reprocess_total = len(reprocess_rows)
print(f"Phase D: analyzing {reprocess_total} documents with Gemini...")

for idx, row in enumerate(reprocess_rows, 1):
    doc_id  = row["doc_id"]
    summary = row["summary"]

    try:
        analysis = get_analysis(summary)

        if analysis is not None and all(k in analysis for k in ("industry", "function", "seniority")):
            new_doc = {
                "profileUrl":     row["profileUrl"],
                "lh_id":          row["lh_id"],
                "industry":       analysis["industry"],
                "function":       analysis["function"],
                "seniority":      analysis["seniority"],
                "summary":        summary,
                "memberDistance": row["memberDistance"],
            }
            analysis_ref.document(doc_id).set(new_doc, retry=my_retry)
        else:
            time.sleep(1)

    except Exception as e:
        print(f"ERROR [{doc_id}]: {e}")
        time.sleep(1)
        continue

    if idx % 100 == 0 or idx == reprocess_total:
        ts = time.strftime("%H:%M:%S")
        print(f"{ts} | Analyzed {idx}/{reprocess_total}")
# Out:
# Phase D: analyzing 6 documents with Gemini...
# 17:53:29 | Analyzed 6/6

# %%
print(f"\n✅ All done — analyzed: {reprocess_total},  skipped: {skipped}")
# Out:
# ✅ All done — analyzed: 6,  skipped: 5

# %%
# Run the collection-to-csv conversion
import subprocess
result = subprocess.run(["python3", "collection-tocsv.py"], capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print(result.stderr)
# Out:
# Number of rows: 27772
# Data saved to analysis.csv and analysis.txt
