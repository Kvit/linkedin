# %%
#  Make analysis of LinkedIn profile data

import os
import json
import time
import pprint
from google.cloud import firestore
from google.api_core import retry
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Initialize the OpenAI client (auto-detects OPENAI_API_KEY from environment)
client = OpenAI()


def show_json(obj):
    display(json.loads(obj.model_dump_json()))


# Initialize Firestore client with specific project ID, only if file is found
if os.path.isfile("vk-linkedin-master-service-account.json"):
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = (
        "vk-linkedin-master-service-account.json"
    )

db = firestore.Client(
    project="vk-linkedin",
    database="linkedin"
)

# Get the 'extracted' collection
extracted_ref = db.collection("extracted")

# analysis collection
analysis_ref = db.collection("analysis")

# %%
# System instructions for analyzing LinkedIn profile summaries
ANALYSIS_INSTRUCTIONS = """You are an expert at analyzing LinkedIn profile summaries.
Analyze the provided profile summary and extract the following information:

1. industry - The primary industry the person works in (e.g., "Technology", "Finance", "Healthcare")
2. function - Their job function/role type (e.g., "Engineering", "Sales", "Marketing", "Operations")
3. seniority - Their seniority level (e.g., "Entry", "Mid", "Senior", "Executive", "C-Level")

Respond ONLY with a valid JSON object in this exact format:
{"industry": "...", "function": "...", "seniority": "..."}

Do not include any other text, markdown formatting, or code blocks."""


def analyze_summary(summary: str) -> dict | None:
    """
    Analyze the summary using OpenAI Responses API.

    Args:
        summary (str): The profile summary to analyze.

    Returns:
        dict | None: Dictionary with industry, function, seniority keys, or None on error.
    """
    # Truncate summary for error messages
    summary_preview = summary[:100] + "..." if len(summary) > 100 else summary
    
    try:
        response = client.responses.create(
            model="gpt-5-mini",
            instructions=ANALYSIS_INSTRUCTIONS,
            input=summary,
        )

        # Check if response has expected structure
        if not hasattr(response, 'output_text'):
            print(f"ERROR: Response missing 'output_text' attribute")
            print(f"Response type: {type(response)}")
            print(f"Response dir: {dir(response)}")
            print(f"Summary: {summary_preview}")
            return None

        # Parse JSON response
        result = json.loads(response.output_text)
        
        # Validate result structure
        required_keys = ['industry', 'function', 'seniority']
        missing_keys = [key for key in required_keys if key not in result]
        
        if missing_keys:
            print(f"ERROR: Response missing required keys: {missing_keys}")
            print(f"Received keys: {list(result.keys())}")
            print(f"Response content: {result}")
            print(f"Summary: {summary_preview}")
            return None
        
        # Check for empty values
        empty_fields = [key for key in required_keys if not result[key] or result[key].strip() == ""]
        if empty_fields:
            print(f"WARNING: Empty values for fields: {empty_fields}")
            print(f"Response: {result}")
            print(f"Summary: {summary_preview}")
        
        return result

    except json.JSONDecodeError as e:
        print(f"ERROR: Failed to decode JSON response")
        print(f"JSON Error: {e}")
        print(f"Raw response: {response.output_text if hasattr(response, 'output_text') else 'N/A'}")
        print(f"Summary: {summary_preview}")
        return None
    except AttributeError as e:
        print(f"ERROR: Attribute error accessing response")
        print(f"Error: {e}")
        print(f"Response type: {type(response)}")
        print(f"Summary: {summary_preview}")
        return None
    except Exception as e:
        print(f"ERROR: Unexpected error analyzing summary")
        print(f"Error type: {type(e).__name__}")
        print(f"Error message: {e}")
        print(f"Summary: {summary_preview}")
        import traceback
        traceback.print_exc()
        return None

# %%
# helper function to analyze the summary
def get_analysis(summary: str) -> dict | None:
    """
    Get analysis of a profile summary.

    Args:
        summary (str): The summary to analyze.

    Returns:
        dict | None: Analysis result or None on error.
    """
    try:
        return analyze_summary(summary)
    except Exception as e:
        print(f"Error analyzing summary: {e}")
        return None

# %%
# helper function get member distance
def get_member_distance(doc_dict) -> int:
    """
    Extract member distance from various data formats.
    
    Handles:
    - Nested dict: {'memberDistance': {'memberDistance': 'DISTANCE_3', ...}}
    - Direct integer: {'memberDistance': 3}
    - Direct string: {'memberDistance': 'DISTANCE_3'}
    - Out of network: {'memberDistance': 'OUT_OF_NETWORK'} -> returns -1
    """
    try:
        member_dist = doc_dict.get("memberDistance")
        
        if member_dist is None:
            return 0
        
        # If it's a dict, extract the 'memberDistance' field
        if isinstance(member_dist, dict):
            str_distance = member_dist.get("memberDistance")
            if str_distance is None:
                return 0
        else:
            str_distance = member_dist
        
        # If it's already an integer, return it
        if isinstance(str_distance, int):
            return str_distance
        
        # If it's a string, try to parse the distance
        if isinstance(str_distance, str):
            if str_distance == "OUT_OF_NETWORK":
                return 0
            # Match "DISTANCE_X" pattern
            if str_distance.startswith("DISTANCE_") and str_distance[-1:].isdigit():
                return int(str_distance[-1:])
            return 0
        
        return 0
        
    except Exception as e:
        print(f"Error getting member distance: {e}, member_dist: {doc_dict.get('memberDistance')}")
        return 0

# %%
#  statistics 

# Get all documents from analysis collection
analysis_docs = list(analysis_ref.stream())

# Initialize counters
total_docs = len(analysis_docs)
with_all_categories = 0
missing_categories = 0
with_summary = 0
without_summary = 0
with_industry = 0
with_function = 0
with_seniority = 0
with_summary_no_categories = 0

# Count statistics
for doc in analysis_docs:
    doc_data = doc.to_dict()
    
    # Check categories
    has_industry = bool(doc_data.get("industry"))
    has_function = bool(doc_data.get("function"))
    has_seniority = bool(doc_data.get("seniority"))
    
    if has_industry:
        with_industry += 1
    if has_function:
        with_function += 1
    if has_seniority:
        with_seniority += 1
    
    if has_industry and has_function and has_seniority:
        with_all_categories += 1
    else:
        missing_categories += 1
    
    # Check summary
    summary = doc_data.get("summary", "")
    has_summary = summary and len(summary.strip()) > 50
    
    if has_summary:
        with_summary += 1
    else:
        without_summary += 1
    
    # Check for summary but no categories
    if has_summary and not (has_industry and has_function and has_seniority):
        with_summary_no_categories += 1

# Display statistics
print("=" * 60)
print("ANALYSIS COLLECTION STATISTICS")
print("=" * 60)
print(f"\nTotal documents: {total_docs}")
print("\n--- Category Statistics ---")
print(f"With all 3 categories (industry, function, seniority): {with_all_categories} ({with_all_categories/total_docs*100:.1f}%)")
print(f"Missing one or more categories: {missing_categories} ({missing_categories/total_docs*100:.1f}%)")
print(f"\nBreakdown by field:")
print(f"  - With industry: {with_industry} ({with_industry/total_docs*100:.1f}%)")
print(f"  - With function: {with_function} ({with_function/total_docs*100:.1f}%)")
print(f"  - With seniority: {with_seniority} ({with_seniority/total_docs*100:.1f}%)")
print("\n--- Summary Statistics ---")
print(f"With summary: {with_summary} ({with_summary/total_docs*100:.1f}%)")
print(f"Without summary: {without_summary} ({without_summary/total_docs*100:.1f}%)")
print(f"With summary but no categories yet: {with_summary_no_categories} ({with_summary_no_categories/total_docs*100:.1f}%)")
print("=" * 60)
# Out:
# ...
# ANALYSIS COLLECTION STATISTICS
# ...
#
# Total documents: 27511
#
# --- Category Statistics ---
# With all 3 categories (industry, function, seniority): 12838 (46.7%)
# Missing one or more categories: 14673 (53.3%)
#
# Breakdown by field:
#   - With industry: 12838 (46.7%)
#   - With function: 12838 (46.7%)
#   - With seniority: 12838 (46.7%)
#
# --- Summary Statistics ---
# With summary: 12838 (46.7%)
# Without summary: 14673 (53.3%)
# With summary but no categories yet: 0 (0.0%)
# ...

# %%
# process all documents in collection `extracted` via generator

# retry policy with custom parameters
# reference https://cloud.google.com/spanner/docs/custom-timeout-and-retry?hl=en
my_retry = retry.Retry(
    initial_delay=0.5,  # Initial delay of 0.5 seconds
    timeout=60,  # Maximum timeout of 60 seconds
    multiplier=2,  # Increase delay by 2x on each retry
    retry_count=10,  # Retry up to 10 times
)

# get docs
docs = extracted_ref.stream()
print_one = True

# save docs to list
doc_list = list(docs)

print("number of extracted documents: ", len(doc_list))

# process docs from the list
for doc in doc_list:
    doc_dict = doc.to_dict()

    # print one document
    if print_one:
        pprint.pprint(doc_dict)
        print_one = False

    doc_id = doc.id
    doc_ref = analysis_ref.document(doc_id)

    # safely get summary
    summary = doc_dict.get("summary", "")
    summary = summary.replace("\n", " ")

    # reprocess flag
    reprocess = False

    # fetch existing analysis document once
    existing_snapshot = doc_ref.get(retry=my_retry)

    if not existing_snapshot.exists:
        # new document - needs processing
        reprocess = True
    else:
        existing_data = existing_snapshot.to_dict()
        existing_summary = existing_data.get("summary", "")

        # check if summary has changed
        if existing_summary != summary:
            reprocess = True

        # check if categories are missing (has summary but no analysis)
        has_categories = (
            bool(existing_data.get("industry"))
            and bool(existing_data.get("function"))
            and bool(existing_data.get("seniority"))
        )
        if not has_categories and len(summary) > 50:
            reprocess = True

    # check if document should be reprocessed
    if reprocess:
        if len(summary) > 50:
            # get analysis of summary via OpenAI
            try:
                analysis = get_analysis(summary)

                if analysis is not None:
                    if (
                        "industry" in analysis
                        and "function" in analysis
                        and "seniority" in analysis
                    ):
                        new_doc = {
                            "profileUrl": doc_dict.get("profileUrl", ""),
                            "lh_id": doc_dict.get("lhId", ""),
                            "industry": analysis["industry"],
                            "function": analysis["function"],
                            "seniority": analysis["seniority"],
                            "summary": summary,
                            "memberDistance": get_member_distance(doc_dict),
                        }

                        # create/update document in analysis collection
                        analysis_ref.document(doc_id).set(new_doc, retry=my_retry)

                else:
                    # wait for 1 second before trying again
                    time.sleep(1)
            except Exception as e:
                print(e)
                time.sleep(1)
                continue
    else:
        # update existing document fields without wiping categories
        update_doc = {
            "profileUrl": doc_dict.get("profileUrl", ""),
            "lh_id": doc_dict.get("lhId", ""),
            "summary": summary,
            "memberDistance": get_member_distance(doc_dict),
        }

        analysis_ref.document(doc_id).set(update_doc, merge=True, retry=my_retry)
